# %% [markdown]
# array and basics

# %%
import numpy as np

# %% [markdown]
# Creating array from list

# %%
array_1d = np.array([1,2,3,4,5])
print(array_1d)
print(array_1d[2])
# Out:
# [1 2 3 4 5]
# 3

# %%
array_2d = np.array([[1,2,3], [4,5,6]])
print(array_2d)
# Out:
# [[1 2 3]
#  [4 5 6]]
